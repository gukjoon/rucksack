# %%
import numpy as np
import os
import urllib
import gzip
import struct

# %%
def download_data(url, force_download=True): 
    fname = url.split("/")[-1]
    if force_download or not os.path.exists(fname):
        urllib.urlretrieve(url, fname)
    return fname

def read_data(label_url, image_url):
    with gzip.open(download_data(label_url)) as flbl:
        magic, num = struct.unpack(">II", flbl.read(8))
        label = np.fromstring(flbl.read(), dtype=np.int8)
    with gzip.open(download_data(image_url), 'rb') as fimg:
        magic, num, rows, cols = struct.unpack(">IIII", fimg.read(16))
        image = np.fromstring(fimg.read(), dtype=np.uint8).reshape(len(label), rows, cols)
    return (label, image)

# %%
path='http://yann.lecun.com/exdb/mnist/'
(train_lbl, train_img) = read_data(
    path+'train-labels-idx1-ubyte.gz', path+'train-images-idx3-ubyte.gz')
(val_lbl, val_img) = read_data(
    path+'t10k-labels-idx1-ubyte.gz', path+'t10k-images-idx3-ubyte.gz')

# %%
import mxnet as mx

def to4d(img):
    return img.reshape(img.shape[0], 1, 28, 28).astype(np.float32)/255

batch_size = 100
train_iter = mx.io.NDArrayIter(to4d(train_img), train_lbl, batch_size, shuffle=True)
val_iter = mx.io.NDArrayIter(to4d(val_img), val_lbl, batch_size)

# %%
# Create a place holder variable for the input data
data = mx.sym.Variable('data')
# Flatten the data from 4-D shape (batch_size, num_channel, width, height) 
# into 2-D (batch_size, num_channel*width*height)
data = mx.sym.Flatten(data=data)

# The first fully-connected layer
fc1  = mx.sym.FullyConnected(data=data, name='fc1', num_hidden=128)

# The second fully-connected layer and the according activation function
fc2  = mx.sym.FullyConnected(data=fc1, name='fc2', num_hidden = 64)

# The thrid fully-connected layer, note that the hidden size should be 10, which is the number of unique digits
fc3  = mx.sym.FullyConnected(data=fc2, name='fc3', num_hidden=10)
# The softmax and loss layer
mlp  = mx.sym.SoftmaxOutput(data=fc3, name='softmax')

# We visualize the network structure with output size (the batch_size is ignored.)
shape = {"data" : (batch_size, 1, 28, 28)}
mx.viz.plot_network(symbol=mlp, shape=shape)

# %%
# @@@ AUTOTEST_OUTPUT_IGNORED_CELL
import logging
logging.getLogger().setLevel(logging.DEBUG)

model = mx.model.FeedForward(
    symbol = mlp,       # network structure
    num_epoch = 10,     # number of data passes for training 
    learning_rate = 0.1 # learning rate of SGD 
)
model.fit(
    X=train_iter,       # training data
    eval_data=val_iter, # validation data
    batch_end_callback = mx.callback.Speedometer(batch_size, 200) # output progress for each 200 data batches
)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#
# /mxnet/python/mxnet/model.py:516: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.
#   self.initializer(k, v)
# INFO:root:Start training with [cpu(0)]
# INFO:root:Epoch[0] Batch [200]	Speed: 29202.88 samples/sec	Train-accuracy=0.110900
# INFO:root:Epoch[0] Batch [400]	Speed: 28453.72 samples/sec	Train-accuracy=0.173850
# INFO:root:Epoch[0] Batch [600]	Speed: 29856.76 samples/sec	Train-accuracy=0.537000
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=2.158
# INFO:root:Epoch[0] Validation-accuracy=0.782600
# INFO:root:Epoch[1] Batch [200]	Speed: 33340.56 samples/sec	Train-accuracy=0.817550
# INFO:root:Epoch[1] Batch [400]	Speed: 29834.93 samples/sec	Train-accuracy=0.844700
# INFO:root:Epoch[1] Batch [600]	Speed: 29543.50 samples/sec	Train-accuracy=0.852650
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=1.961
# INFO:root:Epoch[1] Validation-accuracy=0.867300
# INFO:root:Epoch[2] Batch [200]	Speed: 29778.47 samples/sec	Train-accuracy=0.873900
# INFO:root:Epoch[2] Batch [400]	Speed: 30407.19 samples/sec	Train-accuracy=0.882100
# INFO:root:Epoch[2] Batch [600]	Speed: 26511.34 samples/sec	Train-accuracy=0.884550
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=2.093
# INFO:root:Epoch[2] Validation-accuracy=0.890600
# INFO:root:Epoch[3] Batch [200]	Speed: 30990.80 samples/sec	Train-accuracy=0.889550
# INFO:root:Epoch[3] Batch [400]	Speed: 33377.28 samples/sec	Train-accuracy=0.895000
# INFO:root:Epoch[3] Batch [600]	Speed: 30030.49 samples/sec	Train-accuracy=0.896050
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=1.930
# INFO:root:Epoch[3] Validation-accuracy=0.900300
# INFO:root:Epoch[4] Batch [200]	Speed: 29073.70 samples/sec	Train-accuracy=0.902600
# INFO:root:Epoch[4] Batch [400]	Speed: 30257.10 samples/sec	Train-accuracy=0.902750
# INFO:root:Epoch[4] Batch [600]	Speed: 29349.23 samples/sec	Train-accuracy=0.902750
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=2.040
# INFO:root:Epoch[4] Validation-accuracy=0.905700
# INFO:root:Epoch[5] Batch [200]	Speed: 33132.17 samples/sec	Train-accuracy=0.905800
# INFO:root:Epoch[5] Batch [400]	Speed: 30858.62 samples/sec	Train-accuracy=0.906000
# INFO:root:Epoch[5] Batch [600]	Speed: 31312.82 samples/sec	Train-accuracy=0.906000
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=1.898
# INFO:root:Epoch[5] Validation-accuracy=0.906100
# INFO:root:Epoch[6] Batch [200]	Speed: 30794.53 samples/sec	Train-accuracy=0.907300
# INFO:root:Epoch[6] Batch [400]	Speed: 31080.36 samples/sec	Train-accuracy=0.908050
# INFO:root:Epoch[6] Batch [600]	Speed: 31571.38 samples/sec	Train-accuracy=0.908600
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=1.934
# INFO:root:Epoch[6] Validation-accuracy=0.909200
# INFO:root:Epoch[7] Batch [200]	Speed: 32165.11 samples/sec	Train-accuracy=0.911400
# INFO:root:Epoch[7] Batch [400]	Speed: 29525.65 samples/sec	Train-accuracy=0.912750
# INFO:root:Epoch[7] Batch [600]	Speed: 27513.87 samples/sec	Train-accuracy=0.913000
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=2.035
# INFO:root:Epoch[7] Validation-accuracy=0.912400
# INFO:root:Epoch[8] Batch [200]	Speed: 28274.55 samples/sec	Train-accuracy=0.915700
# INFO:root:Epoch[8] Batch [400]	Speed: 31527.14 samples/sec	Train-accuracy=0.916700
# INFO:root:Epoch[8] Batch [600]	Speed: 30458.56 samples/sec	Train-accuracy=0.915450
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=2.008
# INFO:root:Epoch[8] Validation-accuracy=0.915900
# INFO:root:Epoch[9] Batch [200]	Speed: 31912.18 samples/sec	Train-accuracy=0.918450
# INFO:root:Epoch[9] Batch [400]	Speed: 27125.56 samples/sec	Train-accuracy=0.919400
# INFO:root:Epoch[9] Batch [600]	Speed: 30384.93 samples/sec	Train-accuracy=0.917250
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=2.031
# INFO:root:Epoch[9] Validation-accuracy=0.916800
