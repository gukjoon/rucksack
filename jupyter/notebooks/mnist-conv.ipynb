# %%
import numpy as np
import os
import urllib
import gzip
import struct

# %%
def download_data(url, force_download=True): 
    fname = url.split("/")[-1]
    if force_download or not os.path.exists(fname):
        urllib.urlretrieve(url, fname)
    return fname

def read_data(label_url, image_url):
    with gzip.open(download_data(label_url)) as flbl:
        magic, num = struct.unpack(">II", flbl.read(8))
        label = np.fromstring(flbl.read(), dtype=np.int8)
    with gzip.open(download_data(image_url), 'rb') as fimg:
        magic, num, rows, cols = struct.unpack(">IIII", fimg.read(16))
        image = np.fromstring(fimg.read(), dtype=np.uint8).reshape(len(label), rows, cols)
    return (label, image)

# %%
path='http://yann.lecun.com/exdb/mnist/'
(train_lbl, train_img) = read_data(
    path+'train-labels-idx1-ubyte.gz', path+'train-images-idx3-ubyte.gz')
(val_lbl, val_img) = read_data(
    path+'t10k-labels-idx1-ubyte.gz', path+'t10k-images-idx3-ubyte.gz')

# %%
import mxnet as mx

def to4d(img):
    return img.reshape(img.shape[0], 1, 28, 28).astype(np.float32)/255

batch_size = 100
train_iter = mx.io.NDArrayIter(to4d(train_img), train_lbl, batch_size, shuffle=True)
val_iter = mx.io.NDArrayIter(to4d(val_img), val_lbl, batch_size)

# %%
data = mx.sym.var('data')
# first conv layer
conv1 = mx.sym.Convolution(data=data, kernel=(5,5), num_filter=20)
tanh1 = mx.sym.Activation(data=conv1, act_type="tanh")
pool1 = mx.sym.Pooling(data=tanh1, pool_type="max", kernel=(2,2), stride=(2,2))
# second conv layer
conv2 = mx.sym.Convolution(data=pool1, kernel=(5,5), num_filter=50)
tanh2 = mx.sym.Activation(data=conv2, act_type="tanh")
pool2 = mx.sym.Pooling(data=tanh2, pool_type="max", kernel=(2,2), stride=(2,2))
# first fullc layer
flatten = mx.sym.flatten(data=pool2)
fc1 = mx.symbol.FullyConnected(data=flatten, num_hidden=500)
tanh3 = mx.sym.Activation(data=fc1, act_type="tanh")
# second fullc
fc2 = mx.sym.FullyConnected(data=tanh3, num_hidden=10)
# softmax loss
lenet = mx.sym.SoftmaxOutput(data=fc2, name='softmax')

shape = {"data" : (batch_size, 1, 28, 28)}
mx.viz.plot_network(symbol=lenet, shape=shape)

# %%
# @@@ AUTOTEST_OUTPUT_IGNORED_CELL
import logging
logging.getLogger().setLevel(logging.DEBUG)

model = mx.model.FeedForward(
    symbol = lenet,       # network structure
    num_epoch = 10,     # number of data passes for training 
    learning_rate = 0.1 # learning rate of SGD 
)
model.fit(
    X=train_iter,       # training data
    eval_data=val_iter, # validation data
    batch_end_callback = mx.callback.Speedometer(batch_size, 200) # output progress for each 200 data batches
)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#
# /mxnet/python/mxnet/model.py:516: DeprecationWarning: Calling initializer with init(str, NDArray) has been deprecated.please use init(mx.init.InitDesc(...), NDArray) instead.
#   self.initializer(k, v)
# INFO:root:Start training with [cpu(0)]
# INFO:root:Epoch[0] Batch [200]	Speed: 795.65 samples/sec	Train-accuracy=0.112400
# INFO:root:Epoch[0] Batch [400]	Speed: 768.55 samples/sec	Train-accuracy=0.113550
# INFO:root:Epoch[0] Batch [600]	Speed: 733.97 samples/sec	Train-accuracy=0.109750
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=78.491
# INFO:root:Epoch[0] Validation-accuracy=0.113500
# INFO:root:Epoch[1] Batch [200]	Speed: 791.06 samples/sec	Train-accuracy=0.461050
# INFO:root:Epoch[1] Batch [400]	Speed: 771.98 samples/sec	Train-accuracy=0.889900
# INFO:root:Epoch[1] Batch [600]	Speed: 766.78 samples/sec	Train-accuracy=0.930100
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=77.369
# INFO:root:Epoch[1] Validation-accuracy=0.946300
# INFO:root:Epoch[2] Batch [200]	Speed: 771.11 samples/sec	Train-accuracy=0.951000
# INFO:root:Epoch[2] Batch [400]	Speed: 782.82 samples/sec	Train-accuracy=0.961750
# INFO:root:Epoch[2] Batch [600]	Speed: 753.66 samples/sec	Train-accuracy=0.967350
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=78.085
# INFO:root:Epoch[2] Validation-accuracy=0.971400
# INFO:root:Epoch[3] Batch [200]	Speed: 795.25 samples/sec	Train-accuracy=0.971950
# INFO:root:Epoch[3] Batch [400]	Speed: 795.16 samples/sec	Train-accuracy=0.975400
# INFO:root:Epoch[3] Batch [600]	Speed: 781.08 samples/sec	Train-accuracy=0.977050
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=75.967
# INFO:root:Epoch[3] Validation-accuracy=0.976900
# INFO:root:Epoch[4] Batch [200]	Speed: 728.21 samples/sec	Train-accuracy=0.980100
# INFO:root:Epoch[4] Batch [400]	Speed: 722.67 samples/sec	Train-accuracy=0.980900
# INFO:root:Epoch[4] Batch [600]	Speed: 734.72 samples/sec	Train-accuracy=0.982600
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=82.461
# INFO:root:Epoch[4] Validation-accuracy=0.981400
# INFO:root:Epoch[5] Batch [200]	Speed: 736.07 samples/sec	Train-accuracy=0.984600
# INFO:root:Epoch[5] Batch [400]	Speed: 763.54 samples/sec	Train-accuracy=0.984250
# INFO:root:Epoch[5] Batch [600]	Speed: 741.82 samples/sec	Train-accuracy=0.985250
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=80.387
# INFO:root:Epoch[5] Validation-accuracy=0.983600
# INFO:root:Epoch[6] Batch [200]	Speed: 749.59 samples/sec	Train-accuracy=0.986950
# INFO:root:Epoch[6] Batch [400]	Speed: 750.28 samples/sec	Train-accuracy=0.986850
# INFO:root:Epoch[6] Batch [600]	Speed: 747.32 samples/sec	Train-accuracy=0.987100
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=80.198
# INFO:root:Epoch[6] Validation-accuracy=0.985500
# INFO:root:Epoch[7] Batch [200]	Speed: 766.43 samples/sec	Train-accuracy=0.988950
# INFO:root:Epoch[7] Batch [400]	Speed: 786.22 samples/sec	Train-accuracy=0.989000
# INFO:root:Epoch[7] Batch [600]	Speed: 796.25 samples/sec	Train-accuracy=0.989150
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=76.749
# INFO:root:Epoch[7] Validation-accuracy=0.986100
# INFO:root:Epoch[8] Batch [200]	Speed: 747.49 samples/sec	Train-accuracy=0.990350
# INFO:root:Epoch[8] Batch [400]	Speed: 741.44 samples/sec	Train-accuracy=0.990800
# INFO:root:Epoch[8] Batch [600]	Speed: 724.62 samples/sec	Train-accuracy=0.990650
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=81.413
# INFO:root:Epoch[8] Validation-accuracy=0.987000
# INFO:root:Epoch[9] Batch [200]	Speed: 695.38 samples/sec	Train-accuracy=0.991500
# INFO:root:Epoch[9] Batch [400]	Speed: 690.41 samples/sec	Train-accuracy=0.991950
# INFO:root:Epoch[9] Batch [600]	Speed: 725.34 samples/sec	Train-accuracy=0.992050
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=85.396
# INFO:root:Epoch[9] Validation-accuracy=0.987000
